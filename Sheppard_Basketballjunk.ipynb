# %%
class Node:
    draft_year=0
    draft_round=1
    draft_selection=2
    draft_team=3
    first_name=4
    last_name=5
    draft_form=6
    def __init__(self, initial_data):
        self.data = initial_data
        data_split = initial_data.split("_")
        self.draftYear = data_split[self.draft_year]
        self.draftRound = data_split[self.draft_round]
        self.draftSelection = data_split[self.draft_selection]
        self.draftTeam = data_split[self.draft_team]
        self.firstName = data_split[self.first_name]
        self.lastName = data_split[self.last_name]
        self.draftFrom = data_split[self.draft_form]
        self.next = None

#class definitions sourced from zybooks and geeks from geeks, then altered
class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, new_node):
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def prepend(self, new_node):
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node

    def insert_after(self, current_node, new_node):
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        elif current_node is self.tail:
            self.tail.next = new_node
            self.tail = new_node
        else:
            new_node.next = current_node.next
            current_node.next = new_node
   
    def remove_after(self, current_node):
        print("Current node=",current_node)
        
        print("current==None", current_node==None)
        print("self.head != None", self.head != None)
        if (current_node == None) and (self.head != None):
            succeeding_node = self.head.next
            self.head = succeeding_node  
            if succeeding_node == None: 
                self.tail = None
        
        elif current_node.next != None:
            print("current_node.next != None", current_node.next != None)
            print("current_node.next",current_node.next )
            succeeding_node = current_node.next.next
            current_node.next = succeeding_node
            if succeeding_node == None: 
                self.tail = current_node

    def printList(self):
      # Output list
        print('LINKED LIST:', end=' ')
        node = self.head
        while node != None:
          print(node.data, end='->')
          node = node.next
        print()

    def search(self, title):
 
        # Initialize current to head
        current = self.head
 
        # loop till current not equal to None
        while current != None:
            if current.title == title:
                return True # data found
             
            current = current.next
         
    
        return False # Data Not found

#Default class definitions end here       

def main():
    basketPlayers = LinkedList()
    raw_file = ' '
    with open('basketballDraft1937-2012.txt','r', encoding = 'utf-16') as file:
        raw_file = file.read() 

        i=0
        for player in raw_file.split('\n'):
            if i > 0 and player:
                node=node(player)
                basketPlayers.append(node)
            i+=1
            
        node = basketPlayers.head
        print(node.data)
        print(node.next.data)


    print('List after adding nodes:', end=' ')
    node = basketPlayers.head
    while node != None:
        print(node.artist)
        node = node.next

main()
