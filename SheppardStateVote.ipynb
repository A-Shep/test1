# %%
import csv

class Node:
    def __init__(self, state, district, name, vote, party):
        self.state = state
        self.district = district
        self.name = name
        self.vote = vote
        self.party = party
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, new_node):
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def prepend(self, new_node):
        if self.head == None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node


    def insert_after(self, current_node, new_node):
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        elif current_node is self.tail:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        else:
            successor_node = current_node.next
            new_node.next = successor_node
            new_node.prev = current_node
            current_node.next = new_node
            successor_node.prev = new_node
   
    def remove(self, current_node):
        successor_node = current_node.next
        predecessor_node = current_node.prev

        if successor_node is not None:
            successor_node.prev = predecessor_node

        if predecessor_node is not None:
            predecessor_node.next = successor_node

        if current_node is self.head:
            self.head = successor_node

        if current_node is self.tail:
            self.tail = predecessor_node                
    def printList(self):
      # Output list
        print('LINKED LIST:', end=' ')
        node = self.head
        while node != None:
          print(node.name,node.party)
          node = node.next
        print()

    def printListReverse(self):
        node = self.tail
        while node != None:
          print(node.name,node.party)
          node = node.prev
        print()
    
    def search(self, Name):
 
        # Initialize current to head
        current = self.head
        voteInfo = []
        # loop till current not equal to None

        while current != None:
            if current.Name == Name:
                voteInfo.append(current)
             
            current = current.next
         
        return voteInfo
    def countNodes(self):  #count the number of nodes in LL
        count = 0
        node = self.head
        while node != None:
          count +=1
          node = node.next
        return count
        
    def partyCount(self):
        total = self.countNodes()
        dem=0
        rep=0
        other=0
        node = self.head
        while node != None:
          if node.party=='Democratic':
            dem+=1
          elif node.party=='Republican':
            rep+=1
          else:
            other+=1
          node = node.next
        print("Democratic Party make up",format(dem/total,'.1%'))
        print("Republican Party make up",format(rep/total,'.1%'))
        print("Other Party make up",format(other/total,'.1%'))

    def yCount(self):
      totalYCt = 0
      repYCt=0
      demYCt=0
      node = self.head
      while node != None:     
        if node.vote == 'YEA':
          totalYCt+=1
          if node.party== 'Democratic':
            demYCt+=1
          else:
            repYCt+=1
        node = node.next
      return totalYCt, demYCt, repYCt
        
def main():
    
    houseVote_list = LinkedList()
    
    with open('house_votes_1965.csv','r', encoding = 'utf-16') as file:
        vote_reader = csv.reader(file, delimiter=',')
        i = 0
        for vote in vote_reader:
            if i>0 and vote:
                node = Node(vote)
                houseVote_list.appened(node)
            i+=1

    node = houseVote_list.head
  
  
  searchID = input("Last name to search for?")
  
  result = houseVote_list.search(searchID)
  if result ==None:
    print("NAME NOT FOUND")
  else:
    for r in result: 
        state = r.state, name = r.name, vote= r.vote 
        format_string='{r.state:<25}{r.name:<25}{r.vote:<5}'
        print (format_string.format(r.state='State name',r.name='Congressman Name',r.vote='Vote'))
    

  
  houseVote_list.partyCount()
  totalYCt, demYCt, repYCt=houseVote_list.yCount()
  print('total yes Count:', totalYCt, '\ntotal democrats voted yes:', demYCt, '\ntotal rebpublicans voted yes:', repYCt)

  houseVote_list.printListReverse()
main()
